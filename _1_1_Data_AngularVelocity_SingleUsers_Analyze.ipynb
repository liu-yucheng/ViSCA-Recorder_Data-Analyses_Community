# %% [markdown]
# ```
# Copyright (C) 2024-2025 Yucheng Liu. Under the GNU AGPL 3.0 License.
# GNU AGPL 3.0 License: https://www.gnu.org/licenses/agpl-3.0.txt .
#
# Copyright (C) 2024-2025 Yucheng Liu. Under the CC-BY-SA 4.0 License.
# CC-BY-SA 4.0 License: https://creativecommons.org/licenses/by-sa/4.0/legalcode.txt .
# ```

# %% [markdown]
# # 1.1. Analyzing Single Users' Angular Velocity Data
#
# Analyzing single users' VR sickness vs. VR locomotion angular velocity data.

# %% [markdown]
# Note the following items.
#
# - We need to run `./_0_1_Data_Shared_Prepare.ipynb` before running the below code blocks.
# - Then, we need to run `./_1_0_Data_AngularVelocity_SingleUsers_Prepare.ipynb` before running the below code blocks.
#
# Read the following data files to analyze from the `./_1_Data_AngularVelocity_SingleUsers` folder.
#
# - `User<Index_User>_ToAnalyze.json`.
#
# Preprocess the following data files to analyze from the `./_1_Data_AngularVelocity_SingleUsers` folder.
#
# - `User<Index_User>_ToAnalyze.json`.
#   - Create a copy of column `"Sickness"` called `"SicknessCategory"` of type `category`.
#
# Analyze the preprocessed data by going through the following steps.
#
# - We marked each step with code comments.
# - Read the preprocessed data.
# - Compute textual descriptive statistics of `"AngularVelocity"`.
# - Compute a graphical category plot of the `"AngularVelocity"` data.
# - Compute textual descriptive statistics of the `"AngularVelocity"` vs. `SicknessCategory == "0"` data.
# - Compute textual descriptive statistics of the `"AngularVelocity"` vs. `SicknessCategory == "1"` data.
# - Compute textual summary of compare means statistical tests on `"AngularVelocity"` items with `SicknessCategory == "0"` vs `SicknessCategory == "1"`.
# - Compute a graphical category plot of the `"AngularVelocity"` vs. `SicknessCategory` data.
# - Compute textual linear regression statistics of the `"AngularVelocity"` vs. `"Sickness"` data.
# - Compute a graphical linear regression plot of the `"AngularVelocity"` vs. `"Sickness"` data.
# - Compute textual [polynomial regression order 4] statistics of the `"AngularVelocity"` vs. `"Sickness"` data.
# - Compute a graphical [polynomial regression order 4] plot of the `"AngularVelocity"` vs. `"Sickness"` data.
# - Compute textual logistic regression statistics of the `"AngularVelocity"` vs. `"Sickness"` data.
# - Compute a graphical logistic regression plot of the `"AngularVelocity"` vs. `"Sickness"` data.
# - Complete analyzing the preprocessed data.

# %%
import json
import os
import sys

import numpy
import pandas
import sklearn.preprocessing as SKLearn_Preprocess
import statsmodels.api as StatsModels_API
import statsmodels.stats.weightstats as weightstats
import seaborn
import matplotlib.pyplot as pyplot

# %matplotlib inline

Path_Self = os.path.abspath(os.path.curdir)
Path_Input = os.path.join(Path_Self, "_1_Data_AngularVelocity_SingleUsers")
Path_Output = os.path.join(Path_Self, "Figures_Computed")
os.makedirs(Path_Output, exist_ok=True)
Path_Output_Texts = os.path.join(Path_Self, "Texts_Computed")
os.makedirs(Path_Output_Texts, exist_ok=True)
Path_Output_Text = os.path.join(Path_Output_Texts, "_1_1_Text_AngularVelocity_SingleUsers.txt")
File_Output_Text = open(Path_Output_Text, "w+")

def print_(*args, **kwargs):
    Files = [
        sys.stdout,
        File_Output_Text,
    ]

    for File_ in Files:
        kwargs["file"] = File_
        print(*args, **kwargs)
        File_.flush()
    # end for
# end def

Indexes_Users = list(range(0, 4, 1))

for Index_User in Indexes_Users:
    print_(f"Begin analyzing data for user {Index_User}")

    # ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== 
    # - Read the preprocessed data.

    Path_Input_Users = os.path.join(Path_Input, f"User{Index_User}_ToAnalyze.json")
    Path_Output_Users = os.path.join(Path_Output, f"User{Index_User}")
    os.makedirs(Path_Output_Users, exist_ok=True)

    def Path_Output_Figure_Find(Path_):
        return os.path.join(Path_Output_Users, Path_)
    # end def

    Data_ = pandas.read_json(Path_Input_Users)
    Data_["SicknessCategory"] = Data_["Sickness"].astype("category")

    print_(
        "Begin Data_\n"
        + Data_.describe().__str__()
        + "\nEnd Data_"
    )

    Data_WithSickness = Data_[Data_["SicknessCategory"] == 1]

    print_(
        "Begin Data_WithSickness\n"
        + Data_WithSickness.describe().__str__()
        + "\nEnd Data_WithSickness"
    )

    Data_WithoutSickness = Data_[Data_["SicknessCategory"] == 0]

    print_(
        "Begin Data_WithoutSickness\n"
        + Data_WithoutSickness.describe().__str__()
        + "\nEnd Data_WithoutSickness"
    )

    # ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== 
    # - Compute textual descriptive statistics of `"AngularVelocity"`.

    print_(
        "\n"
        + f"<<<< User {Index_User}'s Locomotion Angular Velocity Descriptive Statistics >>>>\n"
        + Data_["AngularVelocity"].describe().__str__()
        + "\n"
    )

    print_("\n\n")

    # ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== 
    # - Compute a graphical category plot of the `"AngularVelocity"` data.

    ColorMap = seaborn.hls_palette(
        n_colors=6,
        h=0.01 + 0.66 * (Index_User / (len(Indexes_Users) - 1)),
        l=0.50,
        s=0.50,
    )

    Palette_ = seaborn.color_palette(ColorMap)

    seaborn.set_theme(
        context="notebook",
        style="whitegrid",
        palette=Palette_,
        font="monospace",
    )

    Plot = seaborn.catplot(
        data=Data_,
        x="AngularVelocity",
        kind="boxen",
        native_scale=True,
    )

    Plot.figure.suptitle(f"User {Index_User}'s Locomotion Angular Velocity")
    pyplot.tight_layout(rect=[0, 0, 1, 1])
    pyplot.show()
    
    Plot.figure.savefig(
        Path_Output_Figure_Find(f"fig_User{Index_User}_LocMovAngVel_Stats.png"),
        dpi=Plot.figure.dpi,
        bbox_inches="tight",
    )

    # ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== 
    # - Compute textual descriptive statistics of the `"AngularVelocity"` vs. `SicknessCategory == "0"` data.

    print_(
        "\n"
        + f"<<<< User {Index_User}'s Locomotion Angular Velocity (Without-sickness) Descriptive Statistics >>>>\n"
        + Data_WithoutSickness["AngularVelocity"].describe().__str__()
        + "\n"
    )

    print_("\n\n")

    # ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== 
    # - Compute textual descriptive statistics of the `"AngularVelocity"` vs. `SicknessCategory == "1"` data.

    print_(
        "\n"
        + f"<<<< User {Index_User}'s Locomotion Angular Velocity (With-sickness) Descriptive Statistics >>>>\n"
        + Data_WithSickness["AngularVelocity"].describe().__str__()
        + "\n"
    )

    print_("\n\n")

    # ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== 
    # - Compute textual summary of compare means statistical tests on `"AngularVelocity"` items with `SicknessCategory == "0"` vs `SicknessCategory == "1"`.

    CompareMeans = weightstats.CompareMeans(
        weightstats.DescrStatsW(Data_WithoutSickness["AngularVelocity"]),
        weightstats.DescrStatsW(Data_WithSickness["AngularVelocity"]),
    )

    print_(
        "\n"
        + f"<<<< User {Index_User}'s Locomotion Angular Velocity [With-sickness vs. Without-sickness] Compare Means Statistical Tests >>>>\n"

        + CompareMeans.summary(
            use_t=True,
            alpha=0.05,
            usevar="unequal",
            value=0.0
        ).__str__()

        + "\n"
    )

    print_("\n\n")

    # ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== 
    # - Compute a graphical category plot of the `"AngularVelocity"` vs. `SicknessCategory` data.

    Plot = seaborn.catplot(
        data=Data_,
        x="AngularVelocity",
        y="SicknessCategory",
        hue="SicknessCategory",
        kind="boxen",
        order=[1, 0],
        native_scale=True,
    )

    Plot.figure.suptitle(f"User {Index_User}'s Locomotion Angular Velocity vs. Sickness")
    pyplot.tight_layout(rect=[0, 0, 1, 1])
    pyplot.show()

    Plot.figure.savefig(
        Path_Output_Figure_Find(f"fig_User{Index_User}_LocMovAngVel_VsSick_Stats.png"),
        dpi=Plot.figure.dpi,
        bbox_inches="tight",
    )

    # ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== 
    # - Compute textual linear regression statistics of the `"AngularVelocity"` vs. `"Sickness"` data.
    

    Data_Sickness = Data_["Sickness"]
    Data_AngularVelocity = Data_["AngularVelocity"]
    Polynominal = SKLearn_Preprocess.PolynomialFeatures(degree=1)

    Data_AngularVelocity = Polynominal.fit_transform(
        Data_AngularVelocity.to_numpy().reshape(-1, 1)
    )

    Regression_Model = StatsModels_API.GLS(Data_Sickness, Data_AngularVelocity)
    Regression_Results = Regression_Model.fit()

    print_(
        "\n"
        + f"<<<< User {Index_User}'s [Locomotion Angular Velocity - Sickness] Linear Regression >>>>\n"
        + Regression_Results.summary().__str__()
        + "\n"
    )

    print_("\n\n")

    # ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== 
    # - Compute a graphical linear regression plot of the `"AngularVelocity"` vs. `"Sickness"` data.
    
    Plot = seaborn.jointplot(
        data=Data_,
        x="AngularVelocity",
        y="Sickness",
        kind="reg",
        ylim=[-0.1, 1.9],
        marginal_ticks=True,
        joint_kws={
            "order": 1,
            
            "scatter_kws": {
                "alpha": 0.05
            },
        },
    )

    Plot.figure.suptitle(
        f"User {Index_User}'s [Locomotion Angular Velocity - Sickness]\n"
        + "Linear Regression"
    )

    pyplot.tight_layout(rect=[0, 0, 1, 1])
    pyplot.show()

    Plot.figure.savefig(
        Path_Output_Figure_Find(f"fig_User{Index_User}_LocMovAngVel_VsSick_LinReg.png"),
        dpi=Plot.figure.dpi,
        bbox_inches="tight",
    )

    # ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== 
    # - Compute textual [polynomial regression order 4] statistics of the `"AngularVelocity"` vs. `"Sickness"` data.

    Data_Sickness = Data_["Sickness"]
    Data_AngularVelocity = Data_["AngularVelocity"]
    Polynominal = SKLearn_Preprocess.PolynomialFeatures(degree=4)

    Data_AngularVelocity = Polynominal.fit_transform(
        Data_AngularVelocity.to_numpy().reshape(-1, 1)
    )

    Data_AngularVelocity = StatsModels_API.add_constant(Data_AngularVelocity, prepend=False)
    Regression_Model = StatsModels_API.GLS(Data_Sickness, Data_AngularVelocity)
    Regression_Results = Regression_Model.fit()

    print_(
        "\n"
        + f"<<<< User {Index_User}'s [Locomotion Angular Velocity - Sickness] [Ploynominal Regression Order 4] >>>>\n"
        + Regression_Results.summary().__str__()
        + "\n"
    )

    print_("\n\n")

    # ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== 
    # - Compute a graphical [polynomial regression order 4] plot of the `"AngularVelocity"` vs. `"Sickness"` data.

    Plot = seaborn.jointplot(
        data=Data_,
        x="AngularVelocity",
        y="Sickness",
        kind="reg",
        ylim=[-0.1, 1.9],
        marginal_ticks=True,
        joint_kws={
            "order": 4,
            
            "scatter_kws": {
                "alpha": 0.05
            },
        },
    )

    Plot.figure.suptitle(
        f"User {Index_User}'s [Locomotion Angular Velocity - Sickness]\n"
        + "[Ploynominal Regression Order 4]"
    )

    pyplot.tight_layout(rect=[0, 0, 1, 1])
    pyplot.show()

    Plot.figure.savefig(
        Path_Output_Figure_Find(f"fig_User{Index_User}_LocMovAngVel_VsSick_PolyReg.png"),
        dpi=Plot.figure.dpi,
        bbox_inches="tight",
    )

    # ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== 
    # - Compute textual logistic regression statistics of the `"AngularVelocity"` vs. `"Sickness"` data.

    Data_Sickness = Data_["Sickness"]
    Data_AngularVelocity = Data_["AngularVelocity"]
    Polynominal = SKLearn_Preprocess.PolynomialFeatures(degree=1)

    Data_AngularVelocity = Polynominal.fit_transform(
        Data_AngularVelocity.to_numpy().reshape(-1, 1)
    )

    Data_AngularVelocity = StatsModels_API.add_constant(Data_AngularVelocity, prepend=False)
    Regression_Model = StatsModels_API.Logit(Data_Sickness, Data_AngularVelocity)
    Regression_Results = Regression_Model.fit()
    
    print_(
        "\n"
        + f"<<<< User {Index_User}'s [Locomotion Angular Velocity - Sickness] Logistic Regression >>>>\n"
        + Regression_Results.summary().__str__()
        + "\n"
    )

    print_("\n\n")

    # ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== 
    # - Compute a graphical logistic regression plot of the `"AngularVelocity"` vs. `"Sickness"` data.

    Plot = seaborn.jointplot(
        data=Data_,
        x="AngularVelocity",
        y="Sickness",
        kind="reg",
        ylim=[-0.1, 1.9],
        marginal_ticks=True,
        
        joint_kws={
            "logistic": True,
            
            "scatter_kws": {
                "alpha": 0.05
            },
        },
    )

    Plot.figure.suptitle(
        f"User {Index_User}'s [Locomotion Angular Velocity - Sickness]\n"
        + "Logistic Regression"
    )

    pyplot.tight_layout(rect=[0, 0, 1, 1])
    pyplot.show()

    Plot.figure.savefig(
        Path_Output_Figure_Find(f"fig_User{Index_User}_LocMovAngVel_VsSick_LogReg.png"),
        dpi=Plot.figure.dpi,
        bbox_inches="tight",
    )

    # ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== ==== 
    # - Complete analyzing the preprocessed data.

    print_(f"End analyzing data for user {Index_User}")
    print_("\n\n\n\n")
# end for

File_Output_Text.close()
# Out:
# Begin analyzing data for user 0
# Begin Data_
#               Time  AngularVelocity     Sickness
# count  5785.000000     5.785000e+03  5785.000000
# mean    125.798082     1.976720e+01     0.354365
# std      72.496622     1.603659e+01     0.478362
# min       0.000000     1.884189e-09     0.000000
# 25%      62.933350     5.336670e+00     0.000000
# 50%     124.900024     1.502516e+01     0.000000
# 75%     188.688904     3.290405e+01     1.000000
# max     251.577698     7.695702e+01     1.000000
# End Data_
# Begin Data_WithSickness
#               Time  AngularVelocity  Sickness
# count  2050.000000      2050.000000    2050.0
# mean    127.569688        32.462884       1.0
# std      73.474438        13.982785       0.0
# min       9.444458         0.289031       1.0
# 25%      64.611145        24.699583       1.0
# 50%     111.594452        33.796028       1.0
# 75%     198.077698        41.546229       1.0
# max     249.922180        76.957016       1.0
# End Data_WithSickness
# Begin Data_WithoutSickness
#               Time  AngularVelocity  Sickness
# count  3735.000000     3.735000e+03    3735.0
# mean    124.825715     1.279903e+01       0.0
# std      71.945642     1.241028e+01       0.0
# min       0.000000     1.884189e-09       0.0
# 25%      55.455566     3.937033e+00       0.0
# 50%     128.200012     7.461003e+00       0.0
# 75%     183.755554     1.774100e+01       0.0
# max     251.577698     6.520666e+01       0.0
# End Data_WithoutSickness
#
# <<<< User 0's Locomotion Angular Velocity Descriptive Statistics >>>>
# count    5.785000e+03
# mean     1.976720e+01
# std      1.603659e+01
# min      1.884189e-09
# 25%      5.336670e+00
# 50%      1.502516e+01
# 75%      3.290405e+01
# max      7.695702e+01
# Name: AngularVelocity, dtype: float64
# <<<< User 0's Locomotion Angular Velocity (Without-sickness) Descriptive Statistics >>>>
# count    3.735000e+03
# mean     1.279903e+01
# std      1.241028e+01
# min      1.884189e-09
# 25%      3.937033e+00
# 50%      7.461003e+00
# 75%      1.774100e+01
# max      6.520666e+01
# Name: AngularVelocity, dtype: float64
#
#
#
#
#
# <<<< User 0's Locomotion Angular Velocity (With-sickness) Descriptive Statistics >>>>
# count    2050.000000
# mean       32.462884
# std        13.982785
# min         0.289031
# 25%        24.699583
# 50%        33.796028
# 75%        41.546229
# max        76.957016
# Name: AngularVelocity, dtype: float64
#
#
#
#
#
# <<<< User 0's Locomotion Angular Velocity [With-sickness vs. Without-sickness] Compare Means Statistical Tests >>>>
#                           Test for equality of means
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# subset #1    -19.6639      0.370    -53.202      0.000     -20.389     -18.939
# ==============================================================================
# <<<< User 0's [Locomotion Angular Velocity - Sickness] Linear Regression >>>>
#                             GLS Regression Results
# ==============================================================================
# Dep. Variable:               Sickness   R-squared:                       0.344
# Model:                            GLS   Adj. R-squared:                  0.344
# Method:                 Least Squares   F-statistic:                     3033.
# Date:                Wed, 11 Jun 2025   Prob (F-statistic):               0.00
# Time:                        16:41:26   Log-Likelihood:                -2722.6
# No. Observations:                5785   AIC:                             5449.
# Df Residuals:                    5783   BIC:                             5462.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0085      0.008      1.052      0.293      -0.007       0.024
# x1             0.0175      0.000     55.075      0.000       0.017       0.018
# ==============================================================================
# Omnibus:                       70.441   Durbin-Watson:                   0.076
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               72.857
# Skew:                           0.274   Prob(JB):                     1.51e-16
# Kurtosis:                       2.955   Cond. No.                         40.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# <<<< User 0's [Locomotion Angular Velocity - Sickness] [Ploynominal Regression Order 4] >>>>
#                             GLS Regression Results
# ==============================================================================
# Dep. Variable:               Sickness   R-squared:                       0.367
# Model:                            GLS   Adj. R-squared:                  0.366
# Method:                 Least Squares   F-statistic:                     836.5
# Date:                Wed, 11 Jun 2025   Prob (F-statistic):               0.00
# Time:                        16:41:27   Log-Likelihood:                -2621.2
# No. Observations:                5785   AIC:                             5252.
# Df Residuals:                    5780   BIC:                             5286.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1029      0.018      5.741      0.000       0.068       0.138
# x1            -0.0211      0.004     -4.698      0.000      -0.030      -0.012
# x2             0.0030      0.000     10.124      0.000       0.002       0.004
# x3          -7.05e-05   6.86e-06    -10.281      0.000   -8.39e-05   -5.71e-05
# x4          5.017e-07   5.23e-08      9.587      0.000    3.99e-07    6.04e-07
# ==============================================================================
# Omnibus:                       45.802   Durbin-Watson:                   0.078
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               48.181
# Skew:                           0.195   Prob(JB):                     3.45e-11
# Kurtosis:                       3.219   Cond. No.                     1.03e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.03e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Optimization terminated successfully.
#          Current function value: 0.463674
#          Iterations 6
#
# <<<< User 0's [Locomotion Angular Velocity - Sickness] Logistic Regression >>>>
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               Sickness   No. Observations:                 5785
# Model:                          Logit   Df Residuals:                     5783
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 11 Jun 2025   Pseudo R-squ.:                  0.2868
# Time:                        16:41:29   Log-Likelihood:                -2682.4
# converged:                       True   LL-Null:                       -3760.9
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -2.6638      0.066    -40.211      0.000      -2.794      -2.534
# x1             0.0944      0.002     38.370      0.000       0.090       0.099
# ==============================================================================
# End analyzing data for user 0
#
#
#
#
#
# Begin analyzing data for user 1
# Begin Data_
#               Time  AngularVelocity     Sickness
# count  6257.000000     6.257000e+03  6257.000000
# mean    134.935872     2.133261e+01     0.407384
# std      77.163269     1.796474e+01     0.491387
# min       0.000000     2.565712e-07     0.000000
# 25%      67.988892     5.363080e+00     0.000000
# 50%     135.722212     1.472958e+01     0.000000
# 75%     202.444441     3.642757e+01     1.000000
# max     265.611113     1.105904e+02     1.000000
# End Data_
# Begin Data_WithSickness
#               Time  AngularVelocity  Sickness
# count  2549.000000      2549.000000    2549.0
# mean    139.078488        33.575258       1.0
# std      74.011564        14.933367       0.0
# min       2.922241         0.811222       1.0
# 25%      73.422241        23.379700       1.0
# 50%     147.288881        35.427250       1.0
# 75%     201.622213        44.110661       1.0
# max     251.377775        89.017586       1.0
# End Data_WithSickness
# Begin Data_WithoutSickness
#               Time  AngularVelocity  Sickness
# count  3708.000000     3.708000e+03    3708.0
# mean    132.088103     1.291661e+01       0.0
# std      79.141371     1.474638e+01       0.0
# min       0.000000     2.565712e-07       0.0
# 25%      64.844482     3.765722e+00       0.0
# 50%     129.722214     6.691669e+00       0.0
# 75%     210.499992     1.496403e+01       0.0
# max     265.611113     1.105904e+02       0.0
# End Data_WithoutSickness
#
# <<<< User 1's Locomotion Angular Velocity Descriptive Statistics >>>>
# count    6.257000e+03
# mean     2.133261e+01
# std      1.796474e+01
# min      2.565712e-07
# 25%      5.363080e+00
# 50%      1.472958e+01
# 75%      3.642757e+01
# max      1.105904e+02
# Name: AngularVelocity, dtype: float64
# <<<< User 1's Locomotion Angular Velocity (Without-sickness) Descriptive Statistics >>>>
# count    3.708000e+03
# mean     1.291661e+01
# std      1.474638e+01
# min      2.565712e-07
# 25%      3.765722e+00
# 50%      6.691669e+00
# 75%      1.496403e+01
# max      1.105904e+02
# Name: AngularVelocity, dtype: float64
#
#
#
#
#
# <<<< User 1's Locomotion Angular Velocity (With-sickness) Descriptive Statistics >>>>
# count    2549.000000
# mean       33.575258
# std        14.933367
# min         0.811222
# 25%        23.379700
# 50%        35.427250
# 75%        44.110661
# max        89.017586
# Name: AngularVelocity, dtype: float64
#
#
#
#
#
# <<<< User 1's Locomotion Angular Velocity [With-sickness vs. Without-sickness] Compare Means Statistical Tests >>>>
#                           Test for equality of means
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# subset #1    -20.6586      0.382    -54.042      0.000     -21.408     -19.909
# ==============================================================================
# <<<< User 1's [Locomotion Angular Velocity - Sickness] Linear Regression >>>>
#                             GLS Regression Results
# ==============================================================================
# Dep. Variable:               Sickness   R-squared:                       0.319
# Model:                            GLS   Adj. R-squared:                  0.319
# Method:                 Least Squares   F-statistic:                     2934.
# Date:                Wed, 11 Jun 2025   Prob (F-statistic):               0.00
# Time:                        16:41:43   Log-Likelihood:                -3228.7
# No. Observations:                6257   AIC:                             6461.
# Df Residuals:                    6255   BIC:                             6475.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0777      0.008      9.759      0.000       0.062       0.093
# x1             0.0155      0.000     54.168      0.000       0.015       0.016
# ==============================================================================
# Omnibus:                        2.735   Durbin-Watson:                   0.108
# Prob(Omnibus):                  0.255   Jarque-Bera (JB):                2.720
# Skew:                           0.034   Prob(JB):                        0.257
# Kurtosis:                       2.923   Cond. No.                         43.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# <<<< User 1's [Locomotion Angular Velocity - Sickness] [Ploynominal Regression Order 4] >>>>
#                             GLS Regression Results
# ==============================================================================
# Dep. Variable:               Sickness   R-squared:                       0.387
# Model:                            GLS   Adj. R-squared:                  0.386
# Method:                 Least Squares   F-statistic:                     986.2
# Date:                Wed, 11 Jun 2025   Prob (F-statistic):               0.00
# Time:                        16:41:45   Log-Likelihood:                -2901.7
# No. Observations:                6257   AIC:                             5813.
# Df Residuals:                    6252   BIC:                             5847.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0386      0.015     -2.589      0.010      -0.068      -0.009
# x1             0.0253      0.003      8.063      0.000       0.019       0.031
# x2             0.0004      0.000      2.274      0.023    5.08e-05       0.001
# x3         -1.611e-05   2.98e-06     -5.414      0.000   -2.19e-05   -1.03e-05
# x4          1.028e-07   1.73e-08      5.956      0.000     6.9e-08    1.37e-07
# ==============================================================================
# Omnibus:                        6.718   Durbin-Watson:                   0.117
# Prob(Omnibus):                  0.035   Jarque-Bera (JB):                6.729
# Skew:                          -0.069   Prob(JB):                       0.0346
# Kurtosis:                       3.083   Cond. No.                     1.50e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.5e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Optimization terminated successfully.
#          Current function value: 0.501221
#          Iterations 6
#
# <<<< User 1's [Locomotion Angular Velocity - Sickness] Logistic Regression >>>>
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               Sickness   No. Observations:                 6257
# Model:                          Logit   Df Residuals:                     6255
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 11 Jun 2025   Pseudo R-squ.:                  0.2584
# Time:                        16:41:47   Log-Likelihood:                -3136.1
# converged:                       True   LL-Null:                       -4229.1
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -2.1293      0.054    -39.098      0.000      -2.236      -2.023
# x1             0.0789      0.002     39.502      0.000       0.075       0.083
# ==============================================================================
# End analyzing data for user 1
#
#
#
#
#
# Begin analyzing data for user 2
# Begin Data_
#               Time  AngularVelocity     Sickness
# count  5919.000000     5.919000e+03  5919.000000
# mean    126.227596     2.053447e+01     0.173678
# std      72.684681     1.683884e+01     0.378864
# min       0.000000     1.541572e-07     0.000000
# 25%      63.000004     5.472319e+00     0.000000
# 50%     126.777789     1.573255e+01     0.000000
# 75%     188.666679     3.393009e+01     0.000000
# max     251.677792     8.006045e+01     1.000000
# End Data_
# Begin Data_WithSickness
#               Time  AngularVelocity  Sickness
# count  1028.000000      1028.000000    1028.0
# mean    117.849347        25.672154       1.0
# std      72.197660        16.899780       0.0
# min       6.344444         0.643708       1.0
# 25%      56.311115         8.418710       1.0
# 50%     116.816666        27.436288       1.0
# 75%     184.000013        38.453723       1.0
# max     241.188900        77.985016       1.0
# End Data_WithSickness
# Begin Data_WithoutSickness
#               Time  AngularVelocity  Sickness
# count  4891.000000     4.891000e+03    4891.0
# mean    127.988553     1.945462e+01       0.0
# std      72.671205     1.662701e+01       0.0
# min       0.000000     1.541572e-07       0.0
# 25%      66.222225     5.164066e+00       0.0
# 50%     128.477789     1.282236e+01       0.0
# 75%     190.355568     3.273826e+01       0.0
# max     251.677792     8.006045e+01       0.0
# End Data_WithoutSickness
#
# <<<< User 2's Locomotion Angular Velocity Descriptive Statistics >>>>
# count    5.919000e+03
# mean     2.053447e+01
# std      1.683884e+01
# min      1.541572e-07
# 25%      5.472319e+00
# 50%      1.573255e+01
# 75%      3.393009e+01
# max      8.006045e+01
# Name: AngularVelocity, dtype: float64
# <<<< User 2's Locomotion Angular Velocity (Without-sickness) Descriptive Statistics >>>>
# count    4.891000e+03
# mean     1.945462e+01
# std      1.662701e+01
# min      1.541572e-07
# 25%      5.164066e+00
# 50%      1.282236e+01
# 75%      3.273826e+01
# max      8.006045e+01
# Name: AngularVelocity, dtype: float64
#
#
#
#
#
# <<<< User 2's Locomotion Angular Velocity (With-sickness) Descriptive Statistics >>>>
# count    1028.000000
# mean       25.672154
# std        16.899780
# min         0.643708
# 25%         8.418710
# 50%        27.436288
# 75%        38.453723
# max        77.985016
# Name: AngularVelocity, dtype: float64
#
#
#
#
#
# <<<< User 2's Locomotion Angular Velocity [With-sickness vs. Without-sickness] Compare Means Statistical Tests >>>>
#                           Test for equality of means
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# subset #1     -6.2175      0.578    -10.753      0.000      -7.352      -5.083
# ==============================================================================
# <<<< User 2's [Locomotion Angular Velocity - Sickness] Linear Regression >>>>
#                             GLS Regression Results
# ==============================================================================
# Dep. Variable:               Sickness   R-squared:                       0.020
# Model:                            GLS   Adj. R-squared:                  0.019
# Method:                 Least Squares   F-statistic:                     118.1
# Date:                Wed, 11 Jun 2025   Prob (F-statistic):           2.97e-27
# Time:                        16:42:00   Log-Likelihood:                -2594.9
# No. Observations:                5919   AIC:                             5194.
# Df Residuals:                    5917   BIC:                             5207.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1090      0.008     14.179      0.000       0.094       0.124
# x1             0.0031      0.000     10.868      0.000       0.003       0.004
# ==============================================================================
# Omnibus:                     1521.614   Durbin-Watson:                   0.089
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2971.212
# Skew:                           1.671   Prob(JB):                         0.00
# Kurtosis:                       3.935   Cond. No.                         41.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# <<<< User 2's [Locomotion Angular Velocity - Sickness] [Ploynominal Regression Order 4] >>>>
#                             GLS Regression Results
# ==============================================================================
# Dep. Variable:               Sickness   R-squared:                       0.022
# Model:                            GLS   Adj. R-squared:                  0.021
# Method:                 Least Squares   F-statistic:                     33.00
# Date:                Wed, 11 Jun 2025   Prob (F-statistic):           2.96e-27
# Time:                        16:42:01   Log-Likelihood:                -2588.0
# No. Observations:                5919   AIC:                             5186.
# Df Residuals:                    5914   BIC:                             5219.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1032      0.016      6.624      0.000       0.073       0.134
# x1             0.0012      0.004      0.306      0.759      -0.006       0.009
# x2             0.0003      0.000      1.205      0.228      -0.000       0.001
# x3         -7.846e-06   5.22e-06     -1.504      0.133   -1.81e-05    2.38e-06
# x4          5.679e-08   3.76e-08      1.511      0.131   -1.69e-08     1.3e-07
# ==============================================================================
# Omnibus:                     1513.310   Durbin-Watson:                   0.089
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2945.440
# Skew:                           1.665   Prob(JB):                         0.00
# Kurtosis:                       3.924   Cond. No.                     1.17e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.17e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Optimization terminated successfully.
#          Current function value: 0.452245
#          Iterations 6
#
# <<<< User 2's [Locomotion Angular Velocity - Sickness] Logistic Regression >>>>
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               Sickness   No. Observations:                 5919
# Model:                          Logit   Df Residuals:                     5917
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 11 Jun 2025   Pseudo R-squ.:                 0.02042
# Time:                        16:42:04   Log-Likelihood:                -2676.8
# converged:                       True   LL-Null:                       -2732.6
# Covariance Type:            nonrobust   LLR p-value:                 4.423e-26
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -2.0289      0.059    -34.298      0.000      -2.145      -1.913
# x1             0.0209      0.002     10.615      0.000       0.017       0.025
# ==============================================================================
# End analyzing data for user 2
#
#
#
#
#
# Begin analyzing data for user 3
# Begin Data_
#               Time  AngularVelocity     Sickness
# count  6260.000000     6.260000e+03  6260.000000
# mean    133.019070     1.692752e+01     0.142812
# std      76.231304     1.533610e+01     0.349908
# min       0.000000     9.756368e-08     0.000000
# 25%      67.388891     4.237141e+00     0.000000
# 50%     132.777778     1.053010e+01     0.000000
# 75%     199.022226     2.877804e+01     0.000000
# max     263.533333     1.228169e+02     1.000000
# End Data_
# Begin Data_WithSickness
#              Time  AngularVelocity  Sickness
# count  894.000000       894.000000     894.0
# mean   115.922174        27.553008       1.0
# std     56.553487        13.586085       0.0
# min     24.411110         0.733860       1.0
# 25%     72.722223        18.931414       1.0
# 50%    105.611115        26.623045       1.0
# 75%    151.780557        34.746168       1.0
# max    204.188889       122.816933       1.0
# End Data_WithSickness
# Begin Data_WithoutSickness
#               Time  AngularVelocity  Sickness
# count  5366.000000     5.366000e+03    5366.0
# mean    135.867490     1.515726e+01       0.0
# std      78.679027     1.489016e+01       0.0
# min       0.000000     9.756368e-08       0.0
# 25%      66.366671     3.772093e+00       0.0
# 50%     137.105556     8.166454e+00       0.0
# 75%     208.744444     2.612397e+01       0.0
# max     263.533333     7.678366e+01       0.0
# End Data_WithoutSickness
#
# <<<< User 3's Locomotion Angular Velocity Descriptive Statistics >>>>
# count    6.260000e+03
# mean     1.692752e+01
# std      1.533610e+01
# min      9.756368e-08
# 25%      4.237141e+00
# 50%      1.053010e+01
# 75%      2.877804e+01
# max      1.228169e+02
# Name: AngularVelocity, dtype: float64
# <<<< User 3's Locomotion Angular Velocity (Without-sickness) Descriptive Statistics >>>>
# count    5.366000e+03
# mean     1.515726e+01
# std      1.489016e+01
# min      9.756368e-08
# 25%      3.772093e+00
# 50%      8.166454e+00
# 75%      2.612397e+01
# max      7.678366e+01
# Name: AngularVelocity, dtype: float64
#
#
#
#
#
# <<<< User 3's Locomotion Angular Velocity (With-sickness) Descriptive Statistics >>>>
# count    894.000000
# mean      27.553008
# std       13.586085
# min        0.733860
# 25%       18.931414
# 50%       26.623045
# 75%       34.746168
# max      122.816933
# Name: AngularVelocity, dtype: float64
#
#
#
#
#
# <<<< User 3's Locomotion Angular Velocity [With-sickness vs. Without-sickness] Compare Means Statistical Tests >>>>
#                           Test for equality of means
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# subset #1    -12.3957      0.498    -24.902      0.000     -13.372     -11.419
# ==============================================================================
# <<<< User 3's [Locomotion Angular Velocity - Sickness] Linear Regression >>>>
#                             GLS Regression Results
# ==============================================================================
# Dep. Variable:               Sickness   R-squared:                       0.080
# Model:                            GLS   Adj. R-squared:                  0.080
# Method:                 Least Squares   F-statistic:                     544.1
# Date:                Wed, 11 Jun 2025   Prob (F-statistic):          1.83e-115
# Time:                        16:42:13   Log-Likelihood:                -2047.6
# No. Observations:                6260   AIC:                             4099.
# Df Residuals:                    6258   BIC:                             4113.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0336      0.006      5.314      0.000       0.021       0.046
# x1             0.0065      0.000     23.326      0.000       0.006       0.007
# ==============================================================================
# Omnibus:                     1856.821   Durbin-Watson:                   0.026
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4083.046
# Skew:                           1.764   Prob(JB):                         0.00
# Kurtosis:                       4.790   Cond. No.                         34.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# <<<< User 3's [Locomotion Angular Velocity - Sickness] [Ploynominal Regression Order 4] >>>>
#                             GLS Regression Results
# ==============================================================================
# Dep. Variable:               Sickness   R-squared:                       0.114
# Model:                            GLS   Adj. R-squared:                  0.113
# Method:                 Least Squares   F-statistic:                     200.9
# Date:                Wed, 11 Jun 2025   Prob (F-statistic):          2.38e-162
# Time:                        16:42:13   Log-Likelihood:                -1930.2
# No. Observations:                6260   AIC:                             3870.
# Df Residuals:                    6255   BIC:                             3904.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0711      0.010     -6.806      0.000      -0.092      -0.051
# x1             0.0290      0.002     12.658      0.000       0.024       0.033
# x2            -0.0008      0.000     -6.494      0.000      -0.001      -0.001
# x3          7.281e-06   2.18e-06      3.336      0.001       3e-06    1.16e-05
# x4          -1.57e-08   1.18e-08     -1.334      0.182   -3.88e-08    7.37e-09
# ==============================================================================
# Omnibus:                     1637.229   Durbin-Watson:                   0.030
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3260.036
# Skew:                           1.629   Prob(JB):                         0.00
# Kurtosis:                       4.375   Cond. No.                     1.05e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.05e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Optimization terminated successfully.
#          Current function value: 0.373599
#          Iterations 6
#
# <<<< User 3's [Locomotion Angular Velocity - Sickness] Logistic Regression >>>>
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               Sickness   No. Observations:                 6260
# Model:                          Logit   Df Residuals:                     6258
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 11 Jun 2025   Pseudo R-squ.:                 0.08886
# Time:                        16:42:15   Log-Likelihood:                -2338.7
# converged:                       True   LL-Null:                       -2566.8
# Covariance Type:            nonrobust   LLR p-value:                3.273e-101
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -2.7891      0.068    -41.022      0.000      -2.922      -2.656
# x1             0.0477      0.002     20.754      0.000       0.043       0.052
# ==============================================================================
# End analyzing data for user 3

# %% [markdown]
# ## Congrats!
#
# We have completed this `ipynb` notebook.
